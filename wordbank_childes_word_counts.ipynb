# %%
import os
import sys

# %%
def count_words(cdi_words, utterances, multiwords=False):
    idx = 0
    
    target_counts = {}
    for line in open(cdi_words).readlines()[1:]:
        line = line.split(",")[idx].strip("*").lower()
        if " (" in line:
            line = line.split(" (")[0]
            target_counts[line] = 0
        elif "/" in line:
            line = line.split("/")[0]
            target_counts[line] = 0
        elif " " in line:
            continue
        else:
            target_counts[line] = 0
        sys.stdout.flush()

    speaker_utts = []
    for line in open(utterances).readlines():
        for kk in target_counts.keys():
            if " "+kk+" " in " "+line.lower().strip()+" ":
                target_counts[kk]+=1
    return target_counts

# %%
# Load list of target words (tsv: word original, word unigram, aoa, pos)
cdi_words  = "/home/lea/postdoc/projects/cogsci/data/wordbank_cdi/bglm_aoas_singlewords.csv"

# Load corpus (space-separated plain text)
corpus = "/home/lea/postdoc/projects/cogsci/data/childes/Brent/all_txt/utterances.txt"

word_counts = count_words(cdi_words, corpus, multiwords=True)

total = 0.0
for k,v in word_counts.items():
    print(k, len(k), v)
    total+=v
print("average_frequency", total / len(word_counts))
print("numwords", len(word_counts))
# Out:
# a 1 8377
# about 5 642
# above 5 30
# after 5 62
# airplane 8 45
# all 3 1776
# alligator 9 19
# am 2 111
# an 2 211
# and 3 4784
# animal 6 29
# ankle 5 2
# another 7 370
# ant 3 1
# any 3 252
# apple 5 97
# applesauce 10 102
# are 3 3202
# arm 3 87
# around 6 385
# asleep 6 28
# at 2 1415
# aunt 4 22
# awake 5 14
# away 4 434
# baby 4 1791
# babysitter 10 0
# back 4 1415
# backyard 8 6
# bad 3 139
# ball 4 983
# balloon 7 82
# banana 6 122
# basement 8 14
# basket 6 92
# bat 3 31
# bath 4 125
# bathroom 8 0
# bathtub 7 0
# be 2 1145
# beach 5 6
# beads 5 27
# beans 5 41
# bear 4 418
# because 7 356
# bed 3 187
# bedroom 7 0
# bee 3 80
# before 6 104
# behind 6 69
# belt 4 16
# bench 5 7
# beside 6 1
# better 6 303
# bib 3 103
# bicycle 7 5
# big 3 1021
# bird 4 170
# bite 4 360
# black 5 73
# blanket 7 45
# block 5 94
# blow 4 84
# blue 4 231
# boat 4 49
# book 4 938
# boots 5 5
# bottle 6 224
# bowl 4 129
# box 3 170
# boy 3 1157
# bread 5 90
# break 5 48
# breakfast 9 87
# bring 5 157
# broken 6 14
# broom 5 28
# brother 7 3
# brown 5 103
# brush 5 111
# bubbles 7 85
# bucket 6 31
# bug 3 59
# build 5 52
# bump 4 44
# bunny 5 372
# bus 3 166
# but 3 609
# butter 6 11
# butterfly 9 46
# buttocks 8 0
# button 6 75
# buy 3 55
# by 2 194
# bye 3 118
# cake 4 83
# camera 6 14
# camping 7 1
# candy 5 11
# car 3 281
# careful 7 265
# carrots 7 43
# carry 5 25
# cat 3 115
# catch 5 75
# cereal 6 101
# chair 5 288
# chalk 5 11
# chase 5 16
# cheek 5 9
# cheerios 8 92
# cheese 6 228
# child 5 2
# chin 4 31
# chocolate 9 10
# church 6 1
# circus 6 1
# clap 4 134
# climb 5 70
# clock 5 37
# close 5 286
# closet 6 27
# cloud 5 4
# clown 5 21
# coat 4 45
# cockadoodledoo 14 0
# coffee 6 45
# coke 4 1
# cold 4 193
# comb 4 46
# cook 4 24
# cookie 6 152
# corn 4 21
# couch 5 54
# could 5 260
# country 7 1
# cover 5 28
# cow 3 231
# cowboy 6 3
# cracker 7 44
# crayon 6 26
# crib 4 19
# cry 3 60
# cup 3 211
# cut 3 78
# cute 4 111
# daddy 5 501
# dance 5 49
# dark 4 26
# day 3 201
# deer 4 7
# diaper 6 305
# dinner 6 102
# dirty 5 194
# dish 4 8
# do 2 3543
# doctor 6 23
# does 4 503
# dog 3 231
# doll 4 21
# don't 5 3182
# donkey 6 10
# donut 5 0
# door 4 288
# down 4 1864
# downtown 8 1
# draw 4 11
# drawer 6 29
# drive 5 27
# drop 4 51
# dryer 5 12
# duck 4 149
# dump 4 57
# each 4 14
# ear 3 99
# eat 3 894
# egg 3 107
# elephant 8 97
# empty 5 29
# every 5 30
# eye 3 165
# face 4 241
# fall 4 224
# farm 4 51
# fast 4 107
# feed 4 65
# find 4 331
# fine 4 68
# finger 6 136
# finish 6 104
# fireman 7 0
# firetruck 9 0
# first 5 203
# fit 3 94
# fix 3 80
# flag 4 2
# flower 6 115
# food 4 231
# foot 4 346
# for 3 1976
# fork 4 20
# friend 6 52
# frog 4 41
# full 4 83
# game 4 78
# garage 6 8
# garbage 7 9
# garden 6 18
# gentle 6 54
# get 3 3698
# giraffe 7 29
# girl 4 690
# give 4 591
# glass 5 22
# glasses 7 50
# gloves 6 2
# glue 4 2
# go 2 4985
# good 4 2352
# goose 5 27
# grandma 7 60
# grandpa 7 15
# grapes 6 10
# grass 5 69
# green 5 248
# grrr 4 0
# gum 3 13
# hair 4 361
# hamburger 9 1
# hammer 6 20
# hand 4 334
# happy 5 157
# hard 4 135
# hat 3 180
# hate 4 12
# have 4 1692
# he 2 1362
# head 4 402
# hear 4 289
# heavy 5 86
# helicopter 10 8
# hello 5 510
# help 4 318
# hen 3 17
# her 3 487
# here 4 5196
# hers 4 4
# hi 2 1165
# hide 4 27
# high 4 123
# him 3 650
# his 3 579
# hit 3 155
# hold 4 533
# home 4 169
# horse 5 79
# hose 4 11
# hot 3 250
# house 5 215
# how 3 865
# hug 3 115
# hungry 6 132
# hurry 5 24
# hurt 4 201
# i 1 5673
# ice 3 28
# if 2 570
# inside 6 126
# into 4 115
# is 2 4894
# it 2 8014
# jacket 6 38
# jar 3 19
# jeans 5 6
# jello 5 2
# jelly 5 9
# juice 5 423
# jump 4 122
# keys 4 62
# kick 4 58
# kiss 4 260
# kitchen 7 55
# kitty 5 931
# knee 4 34
# knife 5 0
# knock 5 87
# ladder 6 2
# lady 4 66
# lamb 4 44
# lamp 4 15
# last 4 62
# later 5 109
# leg 3 133
# lick 4 12
# light 5 124
# like 4 2040
# lion 4 59
# lips 4 8
# listen 6 41
# lollipop 8 3
# long 4 130
# look 4 2586
# loud 4 43
# love 4 363
# lunch 5 100
# mad 3 101
# mailman 7 4
# make 4 407
# man 3 267
# me 2 2361
# meat 4 15
# medicine 8 43
# melon 5 0
# meow 4 139
# milk 4 213
# mine 4 44
# mittens 7 28
# mommy 5 2764
# money 5 55
# monkey 6 45
# moo 3 238
# moon 4 49
# moose 5 32
# mop 3 22
# more 4 1125
# morning 7 81
# motorcycle 10 8
# mouse 5 38
# mouth 5 473
# movie 5 16
# much 4 242
# muffin 6 5
# my 2 1466
# myself 6 17
# nail 4 7
# nap 3 84
# napkin 6 5
# naughty 7 8
# necklace 8 3
# new 3 164
# nice 4 472
# night 5 103
# no 2 3772
# noisy 5 10
# none 4 46
# noodles 7 43
# nose 4 533
# not 3 1804
# now 3 1601
# nurse 5 3
# nuts 4 3
# of 2 1585
# off 3 973
# old 3 179
# on 2 5198
# open 4 510
# other 5 358
# ouch 4 89
# our 3 208
# out 3 1508
# outside 7 401
# oven 4 34
# over 4 903
# owl 3 34
# paint 5 3
# pajamas 7 29
# pancake 7 2
# pants 5 176
# paper 5 77
# park 4 17
# party 5 24
# pattycake 9 168
# peas 4 48
# peekaboo 8 361
# pen 3 13
# pencil 6 14
# penguin 7 12
# penis 5 0
# penny 5 3
# people 6 183
# person 6 14
# pick 4 156
# pickle 6 3
# picnic 6 8
# picture 7 86
# pig 3 80
# pillow 6 24
# pizza 5 2
# plant 5 53
# plate 5 19
# play 4 1178
# playground 10 0
# please 6 307
# police 6 2
# pony 4 4
# pool 4 43
# poor 4 38
# popcorn 7 4
# popsicle 8 8
# porch 5 6
# potato 6 15
# potty 5 0
# pour 4 31
# present 7 8
# pretend 7 2
# pretty 6 347
# pretzel 7 3
# pudding 7 25
# pull 4 226
# pumpkin 7 31
# puppy 5 106
# purse 5 23
# push 4 287
# put 3 2660
# puzzle 6 52
# quiet 5 46
# radio 5 19
# rain 4 86
# raisin 6 17
# read 4 477
# red 3 235
# refrigerator 12 42
# ride 4 81
# rip 3 13
# rock 4 92
# roof 4 10
# room 4 156
# rooster 7 49
# run 3 117
# sad 3 29
# salt 4 2
# same 4 50
# sandbox 7 0
# sandwich 8 11
# sauce 5 18
# say 3 2671
# scared 6 24
# scarf 5 5
# school 6 39
# scissors 8 3
# see 3 3601
# shake 5 86
# share 5 34
# she 3 512
# sheep 5 108
# shh 3 5
# shirt 5 175
# shoe 4 168
# shopping 8 15
# shorts 6 29
# shoulder 8 6
# shovel 6 2
# show 4 163
# shower 6 3
# sick 4 41
# sidewalk 8 7
# sing 4 185
# sink 4 25
# sister 6 43
# sit 3 668
# skate 5 0
# sky 3 49
# sled 4 0
# sleep 5 122
# sleepy 6 169
# slipper 7 17
# slow 4 72
# smile 5 29
# snack 5 53
# sneaker 7 0
# snow 4 27
# snowman 7 23
# snowsuit 8 1
# so 2 1340
# soap 4 49
# sock 4 105
# soda 4 7
# sofa 4 5
# soft 4 85
# some 4 1801
# soup 4 25
# spaghetti 9 51
# spill 5 11
# splash 6 46
# spoon 5 212
# sprinkler 9 5
# squirrel 8 26
# stairs 6 81
# stand 5 239
# star 4 59
# stay 4 168
# stick 5 166
# sticky 6 20
# stone 5 0
# stop 4 642
# store 5 24
# story 5 73
# stove 5 10
# strawberry 10 18
# street 6 28
# stroller 8 44
# stuck 5 89
# sun 3 83
# sweater 7 24
# sweep 5 25
# swim 4 14
# table 5 59
# take 4 889
# talk 4 128
# tape 4 35
# taste 5 108
# teacher 7 11
# tear 4 29
# teddybear 9 0
# telephone 9 64
# that 4 7377
# the 3 11295
# their 5 82
# them 4 1194
# then 4 433
# there 5 3808
# these 5 556
# they 4 690
# think 5 863
# thirsty 7 74
# this 4 3725
# those 5 671
# throw 5 379
# tickle 6 167
# tiger 5 22
# tights 6 1
# time 4 420
# tiny 4 12
# tired 5 160
# tissue 6 30
# to 2 4590
# toast 5 19
# today 5 309
# toe 3 105
# tomorrow 8 19
# tongue 6 86
# tonight 7 54
# too 3 873
# tooth 5 41
# toothbrush 10 18
# touch 5 117
# towel 5 60
# tractor 7 30
# train 5 23
# trash 5 64
# tray 4 54
# tree 4 158
# tricycle 8 1
# truck 5 125
# tummy 5 47
# tuna 4 1
# turkey 6 22
# turtle 6 53
# tv 2 0
# uncle 5 18
# under 5 159
# underpants 10 2
# up 2 3257
# us 2 100
# vacuum 6 23
# vagina 6 0
# vanilla 7 13
# vitamins 8 4
# vroom 5 1
# wait 4 320
# wake 4 37
# walk 4 319
# walker 6 21
# was 3 863
# wash 4 284
# we 2 2965
# were 4 222
# wet 3 158
# what 4 5166
# when 4 328
# where 5 1495
# which 5 143
# white 5 70
# who 3 424
# why 3 602
# will 4 386
# wind 4 36
# window 6 127
# windy 5 9
# wipe 4 141
# wish 4 26
# with 4 2092
# wolf 4 20
# woods 5 6
# would 5 331
# write 5 24
# yard 4 38
# yellow 6 231
# yes 3 1187
# yesterday 9 42
# yogurt 6 41
# you 3 23686
# your 4 6578
# yourself 8 218
# yucky 5 66
# zebra 5 17
# zipper 6 78
# zoo 3 10
# average_frequency 432.44736842105266
# numwords 608

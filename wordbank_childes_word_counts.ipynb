# %%
import os

# %%
def count_words(cdi_words, utterances, multiwords=False):
    idx = 1
    if multiwords==True:
        idx=0
    
    target_counts = {}
    for line in open(cdi_words).readlines()[1:]:
        if " (" in line:
            line = line.split(" (")[0]
            target_counts[line] = 0
        else:
            target_counts[line.split(",")[idx]] = 0

    speaker_utts = []
    for line in open(utterances).readlines():
        for kk in target_counts.keys():
            if " "+kk+" " in " "+line.lower().strip()+" ":
                target_counts[kk]+=1
    return target_counts

# %%
# Load list of target words (tsv: word original, word unigram, aoa, pos)
cdi_words  = "/home/lea/postdoc/projects/cogsci/data/wordbank_cdi/wordlist.txt"

# Load corpus (space-separated plain text)
corpus = "/home/lea/postdoc/projects/cogsci/data/childes/Brent/all_txt/utterances.txt"

word_counts = count_words(cdi_words, corpus, multiwords=True)

total = 0.0
for k,v in word_counts.items():
    print(k, v)
    total+=v
print("average_frequency", total / len(word_counts))
# Out:
# airplane 45
# all 1776
# all gone 16
# animal 29
# another 370
# apple 97
# arm 87
# asleep 28
# aunt 22
# away 434
# baa baa 10
# baby 1791
# babysitter 0
# back 1415
# bad 139
# ball 983
# balloon 82
# banana 122
# bath 125
# bathroom 0
# bathtub 0
# beach 6
# beads 27
# bear 418
# bed 187
# bedroom 0
# bee 80
# belly button 2
# bib 103
# bicycle 5
# big 1021
# bird 170
# bite 360
# blanket 45
# block 94
# blow 84
# blue 231
# book 938
# boots 5
# bottle 224
# bowl 129
# box 170
# boy 1157
# bread 90
# break 48
# breakfast 87
# bring 157
# broken 14
# broom 28
# brush 111
# bubbles 85
# bug 59
# bump 44
# bunny 372
# bus 166
# butter 11
# butterfly 46
# button 75
# bye 118
# cake 83
# candy 11
# car 281
# careful 265
# carrots 43
# cat 115
# cereal 101
# chair 288
# cheek 9
# cheerios 92
# cheese 228
# chicken 182
# child 2
# choo choo 32
# church 1
# clean 353
# clock 37
# close 286
# coat 45
# cockadoodledoo 0
# coffee 45
# cold 193
# comb 46
# cookie 152
# couch 54
# cow 231
# cracker 44
# crib 19
# cry 60
# cup 211
# cute 111
# dance 49
# dark 26
# day 201
# deer 7
# diaper 305
# dinner 102
# dirty 194
# dish 8
# dog 231
# doll 21
# don't 3182
# donkey 10
# door 288
# down 1864
# draw 11
# drawer 29
# dress 10
# drink 283
# drive 27
# dry 121
# duck 149
# ear 99
# eat 894
# egg 107
# elephant 97
# empty 29
# eye 165
# face 241
# fall 224
# fast 107
# feed 65
# fine 68
# finger 136
# finish 104
# firetruck 0
# fish 215
# flower 115
# food 231
# foot 346
# fork 20
# frog 41
# garage 8
# garden 18
# gentle 54
# get 3698
# giraffe 29
# girl 690
# give 591
# glass 22
# glasses 50
# go 4985
# good 2352
# good night 28
# goose 27
# grandma 60
# grandpa 15
# grrr 0
# hair 361
# hammer 20
# hand 334
# happy 157
# hard 135
# hat 180
# head 402
# hello 510
# help 318
# her 487
# hi 1165
# high chair 26
# his 579
# hit 155
# home 169
# horse 79
# hot 250
# house 215
# how 865
# hug 115
# hungry 132
# hurry 24
# hurt 201
# i 5673
# ice cream 12
# in 4281
# inside 126
# it 8014
# jacket 38
# jeans 6
# juice 423
# jump 122
# keys 62
# kick 58
# kiss 260
# kitchen 55
# kitty 931
# knee 34
# lady 66
# lamb 44
# lamp 15
# later 109
# leg 133
# light 124
# lion 59
# little 1851
# living room 15
# look 2586
# love 363
# lunch 100
# man 267
# me 2361
# meat 15
# medicine 43
# meow 139
# milk 213
# mine 44
# mommy 2764
# money 55
# monkey 45
# moo 238
# moon 49
# more 1125
# morning 81
# motorcycle 8
# mouse 38
# mouth 473
# my 1466
# nap 84
# naughty 8
# necklace 3
# nice 472
# night 103
# no 3772
# none 46
# nose 533
# not 1804
# now 1601
# off 973
# old 179
# on 5198
# open 510
# orange 134
# other 358
# ouch 89
# out 1508
# outside 401
# oven 34
# owie 3
# owl 34
# pajamas 29
# pants 176
# paper 77
# park 17
# party 24
# pasta 5
# pattycake 168
# peas 48
# peekaboo 361
# pen 13
# penguin 12
# penny 3
# people 183
# person 14
# picture 86
# pig 80
# pillow 24
# pizza 2
# plant 53
# plate 19
# play 1178
# play pen 0
# please 307
# pony 4
# pool 43
# potty 0
# pretty 347
# pull 226
# puppy 106
# purse 23
# push 287
# put 2660
# quack quack 42
# radio 19
# rain 86
# raisin 17
# read 477
# red 235
# refrigerator 42
# ride 81
# rock 92
# rocking chair 0
# run 117
# same 50
# say 2671
# scared 24
# school 39
# scissors 3
# see 3601
# sheep 108
# shh 5
# shirt 175
# shoe 168
# shorts 29
# shovel 2
# show 163
# sick 41
# sing 185
# sink 25
# sky 49
# sleep 122
# sleepy 169
# slide 62
# smile 29
# snow 27
# soap 49
# sock 105
# soft 85
# some 1801
# splash 46
# spoon 212
# squirrel 26
# stairs 81
# star 59
# stop 642
# store 24
# stove 10
# stroller 44
# sun 83
# sweater 24
# swim 14
# swing 62
# table 59
# take 889
# teacher 11
# teddybear 0
# telephone 64
# thank you 6
# that 7377
# there 3808
# thirsty 74
# this 3725
# throw 379
# tickle 167
# tiger 22
# tired 160
# toast 19
# today 309
# toe 105
# tomorrow 19
# tongue 86
# tonight 54
# tooth 41
# toothbrush 18
# touch 117
# towel 60
# toy 224
# train 23
# trash 64
# tree 158
# truck 125
# tummy 47
# turkey 22
# turtle 53
# tv 0
# uh oh 0
# uncle 18
# under 159
# up 3257
# vacuum 23
# vroom 1
# wait 320
# walk 319
# wanna 2329
# wash 284
# watch 324
# water 650
# wet 158
# what 5166
# when 328
# where 1495
# who 424
# why 602
# window 127
# wipe 141
# woof woof 16
# work 153
# write 24
# yard 38
# yes 1187
# you 23686
# your 6578
# yucky 66
# yum yum 54
# zipper 78
# zoo 10
# average_frequency 485.9373368146214

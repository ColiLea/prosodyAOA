# %%
library(glmnet)

# %%
features = read.csv("brent_srilm_features.csv")  # read csv file 

features <- features[complete.cases(features), ]

f1sets <- c("freq")
f2sets <- c("w1","w1w2","p0w1","p0w1w2","p0p1w1","p0p1w1w2")

for(f2 in f2sets) {
    y <- features$y
  
    print(c("====>>>  freq", f2))
    
    x <- features %>% select(freq, f2) %>% data.matrix()

    x.log <- log(x)


    y.scaled <- scale(y)
    x.scaled <- scale(x.log)


    ## 75% of the sample size
    # smp_size <- floor(0.75 * nrow(y.scaled))

    ## set the seed to make your partition reproductible
    # set.seed(123)
    # train_ind <- sample(seq_len(nrow(y.scaled)), size = smp_size)

    xtrain <- head(x.scaled, 225)
    xtest  <- tail(x.scaled,-225)
    ytrain <- head(y.scaled, 225)
    ytest  <- tail(y.scaled,-225)

    
    print(head(xtrain, 5))
    print(head(ytrain, 5))
    print(head(xtest, 5))
    print(head(ytest, 5))
    
    #lambdas <- 10^seq(3, -2, by = -.1)
    
    fit <- glmnet(xtrain, ytrain, alpha = 0, lambda=0.36, standardize=FALSE)

    # summary(fit)

    opt_lambda <- 0.36

    print(opt_lambda)

    print(coef(fit, s=opt_lambda))

    y_predicted <- predict(fit, s = opt_lambda, newx = xtest)

    # Mean squared error
    mse <- mean((ytest - y_predicted)^2)

    # Sum of Squares Total // Error // R^2
    sst <- sum((ytest - mean(ytest))^2)
    sse <- sum((y_predicted - ytest)^2)
    rsq <- 1 - sse / sst

    print(c("MSE", mse))
    print(c("R^2", rsq))

}
# Out:
# [1] "====>>>  freq" "w1"
#         freq         w1
# 1 -0.8262010 -0.0131651
# 2  1.7269509  0.4940598
# 3  0.3780822  1.2487338
# 4 -0.9395244  1.4548000
# 5  0.6284766  0.4717425
#            [,1]
# [1,] -0.4474072
# [2,]  0.8846884
# [3,] -1.7313882
# [4,]  0.2521571
# [5,]  0.7896439
#           freq         w1
# 244 -0.6721481 -0.8308669
# 245 -1.4391660 -0.9922554
# 246  1.4218400  0.8064590
# 247  0.5274616 -0.3035249
# 249 -0.7446861 -0.4322804
#              [,1]
# [226,]  0.4904426
# [227,]  0.1064032
# [228,] -0.3291340
# [229,] -0.2112341
# [230,]  0.7700418
# [1] 0.36
# 3 x 1 sparse Matrix of class "dgCMatrix"
#                        1
# (Intercept) -0.090743328
# freq        -0.258038207
# w1          -0.008781287
# [1] "MSE"               "0.814197846919164"
# [1] "R^2"                 "-0.0441912074748034"
# [1] "====>>>  freq" "w1w2"
#         freq       w1w2
# 1 -0.8262010 -0.5692988
# 2  1.7269509  0.4122113
# 3  0.3780822  1.1454060
# 4 -0.9395244  0.6123292
# 5  0.6284766  0.1613432
#            [,1]
# [1,] -0.4474072
# [2,]  0.8846884
# [3,] -1.7313882
# [4,]  0.2521571
# [5,]  0.7896439
#           freq       w1w2
# 244 -0.6721481 -1.1746781
# 245 -1.4391660 -1.3178606
# 246  1.4218400  0.7277295
# 247  0.5274616  0.3773934
# 249 -0.7446861 -0.3723532
#              [,1]
# [226,]  0.4904426
# [227,]  0.1064032
# [228,] -0.3291340
# [229,] -0.2112341
# [230,]  0.7700418
# [1] 0.36
# 3 x 1 sparse Matrix of class "dgCMatrix"
#                       1
# (Intercept) -0.09137692
# freq        -0.25049477
# w1w2        -0.02418549
# [1] "MSE"               "0.810394434992894"
# [1] "R^2"                 "-0.0393134135739184"
# [1] "====>>>  freq" "p0w1"
#         freq       p0w1
# 1 -0.8262010 -0.4112644
# 2  1.7269509  0.6146360
# 3  0.3780822  1.1738067
# 4 -0.9395244  0.9264229
# 5  0.6284766  0.8394862
#            [,1]
# [1,] -0.4474072
# [2,]  0.8846884
# [3,] -1.7313882
# [4,]  0.2521571
# [5,]  0.7896439
#           freq       p0w1
# 244 -0.6721481 -1.1476290
# 245 -1.4391660 -1.3146804
# 246  1.4218400  0.5364465
# 247  0.5274616  0.2601765
# 249 -0.7446861  0.6663586
#              [,1]
# [226,]  0.4904426
# [227,]  0.1064032
# [228,] -0.3291340
# [229,] -0.2112341
# [230,]  0.7700418
# [1] 0.36
# 3 x 1 sparse Matrix of class "dgCMatrix"
#                       1
# (Intercept) -0.09157719
# freq        -0.24519877
# p0w1        -0.03265272
# [1] "MSE"               "0.808710506936174"
# [1] "R^2"                 "-0.0371538120992887"
# [1] "====>>>  freq" "p0w1w2"
#         freq     p0w1w2
# 1 -0.8262010 -0.8743993
# 2  1.7269509  0.4166236
# 3  0.3780822  0.9608100
# 4 -0.9395244  0.3395647
# 5  0.6284766  0.3718308
#            [,1]
# [1,] -0.4474072
# [2,]  0.8846884
# [3,] -1.7313882
# [4,]  0.2521571
# [5,]  0.7896439
#           freq     p0w1w2
# 244 -0.6721481 -0.9580801
# 245 -1.4391660 -1.3399131
# 246  1.4218400  0.5941182
# 247  0.5274616  0.6213792
# 249 -0.7446861  0.8283513
#              [,1]
# [226,]  0.4904426
# [227,]  0.1064032
# [228,] -0.3291340
# [229,] -0.2112341
# [230,]  0.7700418
# [1] 0.36
# 3 x 1 sparse Matrix of class "dgCMatrix"
#                       1
# (Intercept) -0.09115552
# freq        -0.25558391
# p0w1w2      -0.01577962
# [1] "MSE"               "0.814708648148508"
# [1] "R^2"                 "-0.0448462990529326"
# [1] "====>>>  freq" "p0p1w1"
#         freq     p0p1w1
# 1 -0.8262010 -0.3812268
# 2  1.7269509  0.5926389
# 3  0.3780822  1.2120328
# 4 -0.9395244  0.9267837
# 5  0.6284766  0.8315554
#            [,1]
# [1,] -0.4474072
# [2,]  0.8846884
# [3,] -1.7313882
# [4,]  0.2521571
# [5,]  0.7896439
#           freq     p0p1w1
# 244 -0.6721481 -1.1325454
# 245 -1.4391660 -1.2749681
# 246  1.4218400  0.5707707
# 247  0.5274616  0.2313129
# 249 -0.7446861  0.8612664
#              [,1]
# [226,]  0.4904426
# [227,]  0.1064032
# [228,] -0.3291340
# [229,] -0.2112341
# [230,]  0.7700418
# [1] 0.36
# 3 x 1 sparse Matrix of class "dgCMatrix"
#                       1
# (Intercept) -0.09146260
# freq        -0.24783125
# p0p1w1      -0.02785505
# [1] "MSE"               "0.809715881277807"
# [1] "R^2"                 "-0.0384431830448466"
# [1] "====>>>  freq" "p0p1w1w2"
#         freq   p0p1w1w2
# 1 -0.8262010 -0.8689606
# 2  1.7269509  0.3778348
# 3  0.3780822  1.1093094
# 4 -0.9395244  0.3725078
# 5  0.6284766  0.5198645
#            [,1]
# [1,] -0.4474072
# [2,]  0.8846884
# [3,] -1.7313882
# [4,]  0.2521571
# [5,]  0.7896439
#           freq   p0p1w1w2
# 244 -0.6721481 -0.9565475
# 245 -1.4391660 -1.2432906
# 246  1.4218400  0.5899853
# 247  0.5274616  0.6338239
# 249 -0.7446861  0.9730904
#              [,1]
# [226,]  0.4904426
# [227,]  0.1064032
# [228,] -0.3291340
# [229,] -0.2112341
# [230,]  0.7700418
# [1] 0.36
# 3 x 1 sparse Matrix of class "dgCMatrix"
#                       1
# (Intercept) -0.09104355
# freq        -0.25639526
# p0p1w1w2    -0.01411221
# [1] "MSE"               "0.814705878011113"
# [1] "R^2"                 "-0.0448427464113696"

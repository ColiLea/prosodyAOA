# %%
import os

import pandas

# %%
corpus         = "Brent"
feature_set    = "srilm_features"

feature_file   = os.path.join("/home/lea/postdoc/projects/cogsci/data/childes", 
                              corpus, 
                              "features",
                              feature_set+".csv")

features       = pandas.read_csv(feature_file)
features       = features.dropna()

# %%
predictors        = ['unigram', 'w1', 'w1w2', 'p0w1',  'p0w1w2', 'p0p1w1', 'p0p1w1w2']

sorted_predictors = []

for predictor in predictors:
    sorted_p = features.sort_values([predictor], ascending=[False], inplace=False)[['word',predictor]]
    sorted_predictors.append(sorted_p)
    
print("idx\t", "\t".join(predictors))
for word_idx in range(len(sorted_predictors[0])):
    print(word_idx, end="\t")
    for predictor_idx, sorted_values in enumerate(sorted_predictors):
        print(sorted_values.iloc[[word_idx]]['word'].to_string(header=False, index=False),
              end="\t")
    print()
# Out:
# idx	 unigram	w1	w1w2	p0w1	p0w1w2	p0p1w1	p0p1w1w2
# 0	you	quack	crib	quack	train	quack	train
# 1	it	choo	quack	yum	pen	yum	pen
# 2	your	yum	pen	choo	lamb	choo	kitchen
# 3	that	pen	lamb	woof	quack	woof	rain
# 4	on	tickle	go	you	yum	you	lamb
# 5	go	on	yum	tickle	go	tickle	quack
# 6	no	down	fast	on	tickle	on	yum
# 7	i	you	you	meow	rain	meow	bus
# 8	what	woof	tickle	lamb	you	lamb	you
# 9	in	me	jump	man	fast	man	on
# 10	get	store	on	cat	on	cat	choo
# 11	this	man	me	splash	me	splash	tickle
# 12	see	splash	blanket	down	jump	down	go
# 13	up	mouse	choo	me	bus	me	gone
# 14	mommy	lamb	man	pen	splash	pen	fast
# 15	there	meow	none	girl	up	girl	store
# 16	put	shirt	down	train	man	train	none
# 17	say	up	up	up	store	boy	girl
# 18	look	boy	cake	boy	careful	up	me
# 19	good	bear	train	rain	none	rain	up
# 20	me	it	grandma	store	choo	store	blanket
# 21	wanna	train	careful	it	down	it	grandma
# 22	all	sheep	store	more	kitchen	more	down
# 23	baby	animal	mouth	bear	night	careful	mouth
# 24	little	go	night	no	blanket	gone	splash
# 25	down	your	splash	careful	girl	bear	careful
# 26	some	more	door	mouse	grandma	no	man
# 27	not	horse	bear	gone	gone	moo	night
# 28	out	girl	gone	your	mouth	mouse	boy
# 29	my	that	sun	moo	boy	your	yard
# 30	now	no	woof	horse	sun	horse	mouse
# 31	back	gone	sheep	go	door	go	pool
# 32	where	see	mouse	see	yard	see	woof
# 33	yes	careful	goose	sheep	mouse	sheep	sheep
# 34	play	good	boy	that	happy	wanna	naughty
# 35	big	cat	happy	wanna	bear	that	party
# 36	hi	juice	more	night	frog	shirt	penguin
# 37	more	old	old	shirt	woof	little	sun
# 38	boy	get	star	in	sheep	house	frog
# 39	kitty	some	girl	little	more	night	goose
# 40	ball	table	kiss	some	no	in	wanna
# 41	off	night	hair	house	party	some	pig
# 42	book	fast	it	old	moon	old	cake
# 43	eat	day	yard	juice	goose	bus	box
# 44	take	not	rain	bus	pig	kitty	star
# 45	how	frog	diaper	keys	ride	juice	jump
# 46	girl	in	sleep	kitty	horse	ball	happy
# 47	stop	none	house	good	that	put	see
# 48	water	sun	that	animal	cake	good	door
# 49	why	moo	window	put	naughty	animal	glass
# 50	his	wanna	ball	get	squirrel	get	more
# 51	give	ball	your	day	it	back	kiss
# 52	man	kiss	work	ball	window	gentle	bear
# 53	nose	there	breakfast	fast	meow	hi	ride
# 54	open	goose	head	back	kiss	not	it
# 55	hello	bird	bus	mommy	your	day	that
# 56	nice	away	finger	bird	star	keys	hair
# 57	her	door	shirt	duck	wanna	mommy	house
# 58	read	mouth	soap	not	glass	goose	old
# 59	mouth	little	frog	hi	in	table	some
# 60	bear	this	in	goose	pool	bird	no
# 61	away	face	home	morning	penguin	fast	work
# 62	head	what	pig	jump	sleep	pool	in
# 63	juice	put	moon	breakfast	see	jump	your
# 64	bunny	chair	bird	another	old	another	ball
# 65	outside	i	meow	frog	house	this	soap
# 66	throw	head	chair	pig	kitty	duck	kitty
# 67	wait	pants	good	this	cat	there	head
# 68	another	mommy	face	there	some	pants	horse
# 69	foot	bottle	horse	table	head	his	shirt
# 70	who	hi	get	gentle	ball	what	meow
# 71	love	jump	some	off	bird	i	home
# 72	hair	nose	no	his	work	pig	bird
# 73	bite	blanket	later	what	diaper	kiss	sleep
# 74	other	bus	see	i	hair	morning	cheese
# 75	tickle	paper	nose	kiss	soap	sky	diaper
# 76	clean	foot	cheese	box	back	off	good
# 77	walk	nice	foot	door	good	breakfast	soft
# 78	moo	pig	away	kitchen	shirt	box	squirrel
# 79	peekaboo	play	ride	away	leg	door	chair
# 80	hand	baby	wanna	knee	moo	frog	face
# 81	when	cheese	party	toe	home	away	crib
# 82	pretty	off	leg	mouth	little	mouth	leg
# 83	help	back	little	lunch	sky	block	back
# 84	watch	leg	kitty	block	his	big	little
# 85	push	my	back	sky	foot	truck	off
# 86	night	wait	juice	big	chair	toe	duck
# 87	wash	book	off	foot	cheese	foot	nose
# 88	diaper	home	cat	my	off	fall	morning
# 89	chair	bread	book	home	get	nice	cat
# 90	bird	duck	not	baby	face	baby	moo
# 91	door	big	there	pool	breakfast	leg	book
# 92	today	out	play	leg	crib	my	truck
# 93	please	hair	turtle	nice	box	home	get
# 94	close	other	his	other	dinner	paper	not
# 95	careful	hand	nice	pants	fall	book	medicine
# 96	drink	his	moo	book	truck	kitchen	fall
# 97	kiss	hat	day	paper	away	lunch	sky
# 98	hot	read	couch	nose	nose	other	rock
# 99	red	cup	button	chair	walk	cheese	bath
# 100	cat	eat	sing	all	morning	face	window
# 101	car	kitty	walk	clean	book	chair	please
# 102	face	bunny	drink	sun	mommy	sun	mommy
# 103	blue	take	mommy	face	button	all	hi
# 104	dog	sing	stairs	bottle	please	head	finger
# 105	food	wash	out	medicine	soft	medicine	breakfast
# 106	house	party	rock	bowl	medicine	knee	put
# 107	toy	tongue	bite	cheese	rock	nose	nice
# 108	gone	how	wait	peekaboo	duck	bowl	dinner
# 109	fish	later	help	soft	play	play	there
# 110	bottle	happy	this	out	juice	bottle	his
# 111	pull	all	animal	head	light	out	play
# 112	cheese	toy	her	read	finger	cow	away
# 113	meow	bye	light	bunny	there	read	wash
# 114	cow	say	bath	hat	not	hat	day
# 115	cup	look	hand	fall	bath	clean	hand
# 116	fall	medicine	say	play	nice	peekaboo	cold
# 117	jump	another	soft	cow	put	none	sing
# 118	bath	love	big	none	wash	cookie	this
# 119	cookie	water	put	hair	out	wait	out
# 120	hat	now	what	ride	hand	how	drink
# 121	spoon	breakfast	hat	wait	bite	bunny	bite
# 122	hurt	toast	duck	cookie	day	cold	foot
# 123	yum	finger	i	arm	lunch	look	what
# 124	milk	dinner	nap	how	what	hair	bread
# 125	day	give	lunch	look	sing	soft	another
# 126	people	yes	baby	wash	this	puppy	my
# 127	bed	sleep	wash	cold	tiger	say	i
# 128	dirty	tree	tree	toast	coat	yes	stairs
# 129	old	toe	bunny	window	mine	arm	hat
# 130	sing	where	dog	say	help	toast	button
# 131	cold	box	fall	yes	i	red	moon
# 132	chicken	house	hi	cereal	say	cereal	towel
# 133	box	fall	pants	watch	drink	wash	juice
# 134	home	morning	my	tongue	clean	happy	paper
# 135	shirt	walk	box	walk	hi	ride	couch
# 136	pants	bite	clean	push	bread	push	bed
# 137	eye	diaper	toe	happy	hat	window	say
# 138	bus	towel	today	eat	bunny	watch	wait
# 139	pattycake	show	water	sleep	wait	wet	peas
# 140	happy	work	shoe	now	towel	tired	bunny
# 141	show	window	table	stop	my	squirrel	fork
# 142	sleepy	pull	bottle	outside	baby	walk	uncle
# 143	wet	button	eat	diaper	stairs	stop	baby
# 144	quack	crib	all	hot	paper	eat	help
# 145	run	push	bug	later	couch	help	later
# 146	bring	soft	bad	tired	her	take	spoon
# 147	hit	her	food	spoon	all	tongue	lunch
# 148	duck	help	other	toy	bed	outside	bowl
# 149	work	bug	please	water	balloon	diaper	yes
# 150	tired	spoon	bread	take	big	now	touch
# 151	hard	gentle	toy	bread	peas	sleep	picture
# 152	tree	lunch	car	people	fork	later	walk
# 153	shoe	purse	paper	puppy	uncle	spoon	her
# 154	under	outside	swing	inside	yes	bread	how
# 155	bad	hot	red	drink	later	hungry	shoe
# 156	orange	wet	cup	bee	cold	hot	all
# 157	wipe	bed	read	doll	refrigerator	bite	big
# 158	bowl	ear	dirty	button	another	bye	animal
# 159	bye	bath	yes	towel	red	button	pants
# 160	truck	why	bowl	cry	touch	hand	nap
# 161	hungry	sick	spoon	squirrel	today	water	read
# 162	window	milk	now	wet	bowl	towel	coat
# 163	baa	bad	hug	dinner	tree	toy	dog
# 164	finger	cereal	kitchen	bye	turtle	snow	bottle
# 165	brush	red	take	help	bib	where	light
# 166	leg	peekaboo	bed	run	shoe	coat	red
# 167	dry	stairs	picture	hand	toy	bad	toy
# 168	inside	hello	hit	where	animal	hello	hug
# 169	light	throw	how	blanket	dog	blanket	bug
# 170	hug	arm	cold	please	nap	drink	bad
# 171	puppy	keys	outside	snow	spoon	doll	doll
# 172	sleep	food	same	bite	bad	party	water
# 173	sheep	drink	pull	red	pants	inside	turtle
# 174	touch	cookie	medicine	hello	bottle	dinner	arm
# 175	egg	cute	cookie	truck	read	please	car
# 176	banana	tired	another	tree	hug	people	stop
# 177	flower	airplane	morning	love	bug	cry	food
# 178	later	puppy	hurt	dog	cow	run	keys
# 179	cereal	yucky	who	party	picture	pull	break
# 180	toe	doll	toast	under	doll	cup	egg
# 181	ear	today	bib	pull	stop	love	clean
# 182	sock	sky	look	today	water	under	cow
# 183	lunch	cow	inside	cup	arm	open	peekaboo
# 184	fast	hurt	milk	sing	car	tree	balloon
# 185	dinner	hard	puppy	who	food	bee	wet
# 186	bib	egg	love	bed	keys	ouch	look
# 187	cute	kitchen	hungry	open	under	dog	inside
# 188	rock	balloon	towel	hit	break	sing	mine
# 189	bread	block	snow	finger	how	stairs	eat
# 190	block	wipe	people	her	look	picture	tree
# 191	ouch	car	stop	work	hit	finger	toe
# 192	breakfast	ride	cow	touch	peekaboo	who	toast
# 193	cheerios	clean	why	ear	egg	give	drawer
# 194	horse	hungry	show	stairs	inside	shoe	today
# 195	finish	who	school	school	push	her	refrigerator
# 196	elephant	dog	squirrel	give	wet	bib	bib
# 197	cake	bib	dinner	ouch	eat	bed	milk
# 198	soft	touch	where	show	toe	work	hurt
# 199	choo	same	stove	bib	who	why	take
# 200	nap	eye	hot	couch	toast	show	outside
# 201	apple	rain	tongue	jacket	other	ear	now
# 202	pig	hit	cute	yucky	outside	hit	tiger
# 203	bubbles	people	cereal	why	milk	yucky	cry
# 204	blow	nap	sink	when	hurt	couch	hit
# 205	button	chicken	purse	shoe	now	touch	other
# 206	picture	shoe	run	hungry	pull	rock	jacket
# 207	sun	stop	wet	sleepy	take	school	hungry
# 208	zipper	sleepy	push	bath	cry	sleepy	under
# 209	morning	bowl	give	picture	watch	car	same
# 210	rain	couch	touch	refrigerator	same	refrigerator	table
# 211	tongue	break	drawer	car	hungry	when	open
# 212	ride	moon	peekaboo	moon	flower	eye	push
# 213	stairs	hug	ear	chicken	jacket	pattycake	sleepy
# 214	balloon	star	throw	light	table	bath	pull
# 215	thirsty	cry	arm	bad	where	jacket	cookie
# 216	bee	pretty	tired	bug	when	bug	hello
# 217	arm	cold	wipe	shorts	cereal	today	show
# 218	paper	run	keys	egg	cookie	chicken	where
# 219	lamb	cake	sleepy	pretty	show	egg	hot
# 220	mouse	grandma	bye	throw	hello	naughty	why
# 221	fine	cheerios	bump	cute	open	baa	people
# 222	trash	fish	sick	wipe	tired	pretty	cup
# 223	swing	open	pretty	pattycake	sleepy	moon	love
# 224	lion	watch	refrigerator	eye	why	tiger	tired
# 225	splash	coat	hello	baa	drawer	wipe	when
# 226	yucky	please	break	coat	wipe	throw	wipe
# 227	lady	dirty	sky	break	hot	break	ouch
# 228	star	inside	bee	balloon	love	shorts	chicken
# 229	telephone	picture	cry	mine	cup	cute	school
# 230	grandma	school	pool	tiger	chicken	light	ear
# 231	kitchen	tonight	chicken	hug	people	hug	sick
# 232	feed	light	balloon	slide	school	balloon	watch
# 233	dance	refrigerator	hard	same	ear	milk	who
# 234	cry	bee	pajamas	food	ouch	food	dirty
# 235	bug	soap	doll	milk	sick	sick	swing
# 236	kick	banana	open	sick	sink	same	puppy
# 237	towel	tummy	tooth	bring	dirty	hard	sink
# 238	slide	pattycake	thirsty	hard	puppy	blue	cereal
# 239	soap	pool	tiger	fish	orange	mine	run
# 240	keys	close	egg	rock	swing	bring	throw
# 241	table	rock	yucky	blue	throw	hurt	banana
# 242	gentle	fork	eye	hurt	run	purse	give
# 243	tummy	blue	money	purse	banana	slide	orange
# 244	woof	fine	fish	airplane	give	airplane	tongue
# 245	tonight	zipper	coat	zipper	tongue	fish	pretty
# 246	couch	sink	orange	banana	pretty	zipper	eye
# 247	turtle	glass	watch	nap	fine	banana	sock
# 248	sky	stroller	cheerios	penguin	elephant	nap	fine
# 249	bump	glasses	under	naughty	cute	close	elephant
# 250	mine	feed	zipper	close	money	dirty	flower
# 251	same	under	airplane	dirty	thirsty	star	money
# 252	plant	finish	glass	thirsty	sock	bubbles	baa
# 253	cracker	truck	elephant	star	slide	penguin	bump
# 254	carrots	knee	swim	stroller	bump	thirsty	thirsty
# 255	peas	yard	block	tonight	baa	tonight	cute
# 256	break	thirsty	gentle	sink	purse	cake	purse
# 257	glasses	money	close	trash	bye	stroller	slide
# 258	coffee	bring	blue	cake	eye	sink	pattycake
# 259	blanket	orange	sock	bubbles	tonight	trash	tonight
# 260	stroller	slide	fine	sock	pattycake	yard	bye
# 261	money	shorts	flower	flower	snow	cheerios	snow
# 262	pool	park	broom	yard	yucky	flower	yucky
# 263	butterfly	dark	bring	cheerios	bee	sock	fish
# 264	comb	pajamas	banana	finish	stove	tummy	stove
# 265	doll	when	tummy	tummy	fish	fine	bee
# 266	coat	tooth	tonight	swing	pajamas	finish	pajamas
# 267	airplane	telephone	when	fine	brush	crib	gentle
# 268	sick	clock	finish	clock	hard	swing	close
# 269	monkey	trash	brush	crib	close	clock	zipper
# 270	medicine	sock	trash	swim	gentle	apple	apple
# 271	moon	plant	truck	orange	apple	orange	blue
# 272	school	flower	telephone	monkey	zipper	turtle	bubbles
# 273	tooth	butterfly	dark	grandma	blue	glass	hard
# 274	frog	squirrel	glasses	brush	cheerios	grandma	cheerios
# 275	jacket	monkey	fork	glass	bubbles	soap	bring
# 276	none	ouch	apple	apple	airplane	glasses	airplane
# 277	snow	blow	feed	soap	pillow	feed	pillow
# 278	clock	baa	slide	glasses	tummy	swim	tummy
# 279	owl	drawer	blow	feed	bring	monkey	lady
# 280	knee	mine	pattycake	turtle	lady	brush	dark
# 281	yard	plate	clock	pillow	dark	dark	block
# 282	refrigerator	elephant	stroller	dark	block	vacuum	plant
# 283	animal	dish	park	park	plant	pillow	tooth
# 284	empty	stove	mine	fork	telephone	park	brush
# 285	shorts	giraffe	naughty	telephone	finish	fork	telephone
# 286	vacuum	turtle	dish	money	tooth	telephone	finish
# 287	hurry	brush	aunt	vacuum	feed	money	feed
# 288	broom	apple	peas	plant	swim	peas	swim
# 289	beads	swing	plant	peas	glasses	plant	glasses
# 290	raisin	bump	ouch	elephant	cheek	elephant	blow
# 291	pajamas	tiger	baa	tooth	broom	tooth	cheek
# 292	drawer	naughty	knee	pajamas	clock	coffee	broom
# 293	drive	peas	shorts	drawer	blow	pajamas	dish
# 294	squirrel	owl	beads	coffee	tomorrow	drawer	owl
# 295	goose	aunt	giraffe	bump	dish	uncle	plate
# 296	sweater	cheek	plate	giraffe	plate	bump	clock
# 297	garden	kick	kick	plate	trash	plate	tomorrow
# 298	store	beads	owl	uncle	aunt	giraffe	trash
# 299	pillow	radio	monkey	dish	dry	dish	vacuum
# 300	write	jacket	pillow	butterfly	owl	butterfly	coffee
# 301	dark	write	butterfly	blow	monkey	blow	dry
# 302	purse	pillow	radio	kick	coffee	radio	aunt
# 303	train	comb	sweater	radio	vacuum	kick	monkey
# 304	aunt	vacuum	comb	stove	knee	dry	knee
# 305	fork	sweater	coffee	beads	stroller	beads	park
# 306	sink	scared	write	dry	park	write	kick
# 307	scared	snow	carrots	write	kick	owl	beads
# 308	pen	coffee	uncle	cheek	beads	broom	shorts
# 309	tiger	broom	dry	owl	shorts	cheek	stroller
# 310	turkey	draw	scared	scared	comb	scared	comb
# 311	glass	dry	vacuum	broom	giraffe	stove	butterfly
# 312	giraffe	motorcycle	jacket	sweater	butterfly	sweater	giraffe
# 313	uncle	uncle	garden	lady	radio	lady	radio
# 314	plate	carrots	hurry	comb	sweater	comb	sweater
# 315	crib	lady	draw	carrots	scared	carrots	hurry
# 316	radio	hurry	motorcycle	draw	carrots	aunt	carrots
# 317	park	raisin	cheek	aunt	write	draw	scared
# 318	teacher	broken	raisin	broken	broken	broken	raisin
# 319	party	turkey	turkey	turkey	garden	turkey	write
# 320	swim	bubbles	bubbles	tomorrow	raisin	tomorrow	broken
# 321	toothbrush	dance	lady	raisin	hurry	raisin	garden
# 322	meat	tomorrow	dance	hurry	dance	garden	dance
# 323	dish	cracker	broken	dance	motorcycle	butter	cracker
# 324	toast	garden	tomorrow	garden	cracker	hurry	draw
# 325	lamp	butter	cracker	motorcycle	toothbrush	dance	motorcycle
# 326	grandpa	swim	toothbrush	butter	draw	motorcycle	toothbrush
# 327	butter	toothbrush	butter	lamp	butter	lamp	butter
# 328	draw	penguin	penguin	cracker	turkey	cracker	turkey
# 329	broken	lion	lion	toothbrush	teacher	toothbrush	teacher
# 330	penguin	lamp	teacher	meat	lion	meat	lion
# 331	donkey	teacher	donkey	lion	donkey	lion	donkey
# 332	stove	donkey	empty	teacher	meat	donkey	meat
# 333	tomorrow	meat	drive	donkey	empty	empty	empty
# 334	cheek	empty	meat	empty	drive	teacher	drive
# 335	naughty	drive	deer	drive	deer	drive	deer
# 336	motorcycle	deer	lamp	grandpa	grandpa	grandpa	grandpa
# 337	pasta	grandpa	grandpa	deer	lamp	deer	lamp
# 338	deer	pasta	pasta	pasta	pasta	pasta	pasta

# %%
import os
import numpy as np
import pandas

# %%
corpus         = "Brent"
feature_set    = "srilm_features"

feature_file   = os.path.join("data/brent_srilm_features.csv")

features       = pandas.read_csv(feature_file)
features       = features.dropna()

# %%
predictors        = ['freq', 'unigram', 'w1', 'w1w2', 'p0w1',  'p0w1w2', 'p0p1w1', 'p0p1w1w2']

sorted_predictors = []
    
    
for predictor in predictors:
    sorted_p = features.sort_values([predictor], ascending=[False], inplace=False)[['word',predictor]]
    sorted_predictors.append(sorted_p)
    
print("idx\t", "\t".join(predictors))
for word_idx in range(len(sorted_predictors[0])):
    print(word_idx, end="\t")
    for predictor_idx, sorted_values in enumerate(sorted_predictors):
        print(sorted_values.iloc[[word_idx]]['word'].to_string(header=False, index=False),
              end="\t")
    print()
# Out:
# idx	 freq	unigram	w1	w1w2	p0w1	p0w1w2	p0p1w1	p0p1w1w2
# 0	you	you	quack	crib	quack	train	quack	train
# 1	it	it	choo	quack	yum	pen	yum	pen
# 2	that	your	yum	pen	choo	lamb	choo	kitchen
# 3	your	that	pen	lamb	woof	quack	woof	rain
# 4	i	on	tickle	go	you	yum	you	lamb
# 5	on	go	on	yum	tickle	go	tickle	quack
# 6	what	no	down	fast	on	tickle	on	yum
# 7	go	i	you	you	meow	rain	meow	bus
# 8	no	what	woof	tickle	lamb	you	lamb	you
# 9	in	in	me	jump	man	fast	man	on
# 10	get	get	store	on	cat	on	cat	choo
# 11	there	this	man	me	splash	me	splash	tickle
# 12	this	see	splash	blanket	down	jump	down	go
# 13	up	up	mouse	choo	me	bus	me	gone
# 14	see	mommy	lamb	man	pen	splash	pen	fast
# 15	mommy	there	meow	none	girl	up	girl	store
# 16	say	put	shirt	down	train	man	train	none
# 17	put	say	up	up	up	store	boy	girl
# 18	look	look	boy	cake	boy	careful	up	me
# 19	me	good	bear	train	rain	none	rain	up
# 20	wanna	me	it	grandma	store	choo	store	blanket
# 21	good	wanna	train	careful	it	down	it	grandma
# 22	down	all	sheep	store	more	kitchen	more	down
# 23	baby	baby	animal	mouth	bear	night	careful	mouth
# 24	all	little	go	night	no	blanket	gone	splash
# 25	not	down	your	splash	careful	girl	bear	careful
# 26	some	some	more	door	mouse	grandma	no	man
# 27	out	not	horse	bear	gone	gone	moo	night
# 28	now	out	girl	gone	your	mouth	mouse	boy
# 29	little	my	that	sun	moo	boy	your	yard
# 30	my	now	no	woof	horse	sun	horse	mouse
# 31	back	back	gone	sheep	go	door	go	pool
# 32	where	where	see	mouse	see	yard	see	woof
# 33	play	yes	careful	goose	sheep	mouse	sheep	sheep
# 34	boy	play	good	boy	that	happy	wanna	naughty
# 35	big	big	cat	happy	wanna	bear	that	party
# 36	yes	hi	juice	more	night	frog	shirt	penguin
# 37	more	more	old	old	shirt	woof	little	sun
# 38	kitty	boy	get	star	in	sheep	house	frog
# 39	hi	kitty	some	girl	little	more	night	goose
# 40	ball	ball	table	kiss	some	no	in	wanna
# 41	book	off	night	hair	house	party	some	pig
# 42	eat	book	fast	it	old	moon	old	cake
# 43	off	eat	day	yard	juice	goose	bus	box
# 44	take	take	not	rain	bus	pig	kitty	star
# 45	how	how	frog	diaper	keys	ride	juice	jump
# 46	stop	girl	in	sleep	kitty	horse	ball	happy
# 47	water	stop	none	house	good	that	put	see
# 48	why	water	sun	that	animal	cake	good	door
# 49	give	why	moo	window	put	naughty	animal	glass
# 50	his	his	wanna	ball	get	squirrel	get	more
# 51	man	give	ball	your	day	it	back	kiss
# 52	nose	man	kiss	work	ball	window	gentle	bear
# 53	open	nose	there	breakfast	fast	meow	hi	ride
# 54	hello	open	goose	head	back	kiss	not	it
# 55	bear	hello	bird	bus	mommy	your	day	that
# 56	her	nice	away	finger	bird	star	keys	hair
# 57	mouth	her	door	shirt	duck	wanna	mommy	house
# 58	read	read	mouth	soap	not	glass	goose	old
# 59	head	mouth	little	frog	hi	in	table	some
# 60	girl	bear	this	in	goose	pool	bird	no
# 61	juice	away	face	home	morning	penguin	fast	work
# 62	who	head	what	pig	jump	sleep	pool	in
# 63	bunny	juice	put	moon	breakfast	see	jump	your
# 64	nice	bunny	chair	bird	another	old	another	ball
# 65	away	outside	i	meow	frog	house	this	soap
# 66	foot	throw	head	chair	pig	kitty	duck	kitty
# 67	outside	wait	pants	good	this	cat	there	head
# 68	wait	another	mommy	face	there	some	pants	horse
# 69	throw	foot	bottle	horse	table	head	his	shirt
# 70	bite	who	hi	get	gentle	ball	what	meow
# 71	peekaboo	love	jump	some	off	bird	i	home
# 72	clean	hair	nose	no	his	work	pig	bird
# 73	tickle	bite	blanket	later	what	diaper	kiss	sleep
# 74	another	other	bus	see	i	hair	morning	cheese
# 75	other	tickle	paper	nose	kiss	soap	sky	diaper
# 76	hair	clean	foot	cheese	box	back	off	good
# 77	hand	walk	nice	foot	door	good	breakfast	soft
# 78	walk	moo	pig	away	kitchen	shirt	box	squirrel
# 79	help	peekaboo	play	ride	away	leg	door	chair
# 80	watch	hand	baby	wanna	knee	moo	frog	face
# 81	moo	when	cheese	party	toe	home	away	crib
# 82	diaper	pretty	off	leg	mouth	little	mouth	leg
# 83	push	help	back	little	lunch	sky	block	back
# 84	love	watch	leg	kitty	block	his	big	little
# 85	bird	push	my	back	sky	foot	truck	off
# 86	when	night	wait	juice	big	chair	toe	duck
# 87	wash	wash	book	off	foot	cheese	foot	nose
# 88	please	diaper	home	cat	my	off	fall	morning
# 89	pretty	chair	bread	book	home	get	nice	cat
# 90	night	bird	duck	not	baby	face	baby	moo
# 91	drink	door	big	there	pool	breakfast	leg	book
# 92	chair	today	out	play	leg	crib	my	truck
# 93	close	please	hair	turtle	nice	box	home	get
# 94	today	close	other	his	other	dinner	paper	not
# 95	car	careful	hand	nice	pants	fall	book	medicine
# 96	door	drink	his	moo	book	truck	kitchen	fall
# 97	careful	kiss	hat	day	paper	away	lunch	sky
# 98	hot	hot	read	couch	nose	nose	other	rock
# 99	kiss	red	cup	button	chair	walk	cheese	bath
# 100	dog	cat	eat	sing	all	morning	face	window
# 101	cow	car	kitty	walk	clean	book	chair	please
# 102	gone	face	bunny	drink	sun	mommy	sun	mommy
# 103	face	blue	take	mommy	face	button	all	hi
# 104	fish	dog	sing	stairs	bottle	please	head	finger
# 105	food	food	wash	out	medicine	soft	medicine	breakfast
# 106	house	house	party	rock	bowl	medicine	knee	put
# 107	red	toy	tongue	bite	cheese	rock	nose	nice
# 108	jump	gone	how	wait	peekaboo	duck	bowl	dinner
# 109	toy	fish	later	help	soft	play	play	there
# 110	pull	bottle	happy	this	out	juice	bottle	his
# 111	bottle	pull	all	animal	head	light	out	play
# 112	bath	cheese	toy	her	read	finger	cow	away
# 113	cheese	meow	bye	light	bunny	there	read	wash
# 114	fall	cow	say	bath	hat	not	hat	day
# 115	meow	cup	look	hand	fall	bath	clean	hand
# 116	cup	fall	medicine	say	play	nice	peekaboo	cold
# 117	cookie	jump	another	soft	cow	put	none	sing
# 118	blue	bath	love	big	none	wash	cookie	this
# 119	spoon	cookie	water	put	hair	out	wait	out
# 120	milk	hat	now	what	ride	hand	how	drink
# 121	dirty	spoon	breakfast	hat	wait	bite	bunny	bite
# 122	cat	hurt	toast	duck	cookie	day	cold	foot
# 123	yum	yum	finger	i	arm	lunch	look	what
# 124	cold	milk	dinner	nap	how	what	hair	bread
# 125	chicken	day	give	lunch	look	sing	soft	another
# 126	hurt	people	yes	baby	wash	this	puppy	my
# 127	old	bed	sleep	wash	cold	tiger	say	i
# 128	pants	dirty	tree	tree	toast	coat	yes	stairs
# 129	hat	old	toe	bunny	window	mine	arm	hat
# 130	bed	sing	where	dog	say	help	toast	button
# 131	people	cold	box	fall	yes	i	red	moon
# 132	duck	chicken	house	hi	cereal	say	cereal	towel
# 133	shirt	box	fall	pants	watch	drink	wash	juice
# 134	show	home	morning	my	tongue	clean	happy	paper
# 135	day	shirt	walk	box	walk	hi	ride	couch
# 136	bus	pants	bite	clean	push	bread	push	bed
# 137	box	eye	diaper	toe	happy	hat	window	say
# 138	sing	bus	towel	today	eat	bunny	watch	wait
# 139	wet	pattycake	show	water	sleep	wait	wet	peas
# 140	home	happy	work	shoe	now	towel	tired	bunny
# 141	eye	show	window	table	stop	my	squirrel	fork
# 142	quack	sleepy	pull	bottle	outside	baby	walk	uncle
# 143	pattycake	wet	button	eat	diaper	stairs	stop	baby
# 144	sleepy	quack	crib	all	hot	paper	eat	help
# 145	shoe	run	push	bug	later	couch	help	later
# 146	tree	bring	soft	bad	tired	her	take	spoon
# 147	bring	hit	her	food	spoon	all	tongue	lunch
# 148	hit	duck	help	other	toy	bed	outside	bowl
# 149	work	work	bug	please	water	balloon	diaper	yes
# 150	run	tired	spoon	bread	take	big	now	touch
# 151	under	hard	gentle	toy	bread	peas	sleep	picture
# 152	wipe	tree	lunch	car	people	fork	later	walk
# 153	happy	shoe	purse	paper	puppy	uncle	spoon	her
# 154	hard	under	outside	swing	inside	yes	bread	how
# 155	brush	bad	hot	red	drink	later	hungry	shoe
# 156	finger	orange	wet	cup	bee	cold	hot	all
# 157	bowl	wipe	bed	read	doll	refrigerator	bite	big
# 158	bye	bowl	ear	dirty	button	another	bye	animal
# 159	leg	bye	bath	yes	towel	red	button	pants
# 160	bad	truck	why	bowl	cry	touch	hand	nap
# 161	light	hungry	sick	spoon	squirrel	today	water	read
# 162	truck	window	milk	now	wet	bowl	towel	coat
# 163	sleep	baa	bad	hug	dinner	tree	toy	dog
# 164	dry	finger	cereal	kitchen	bye	turtle	snow	bottle
# 165	window	brush	red	take	help	bib	where	light
# 166	baa	leg	peekaboo	bed	run	shoe	coat	red
# 167	tired	dry	stairs	picture	hand	toy	bad	toy
# 168	puppy	inside	hello	hit	where	animal	hello	hug
# 169	toe	light	throw	how	blanket	dog	blanket	bug
# 170	flower	hug	arm	cold	please	nap	drink	bad
# 171	hungry	puppy	keys	outside	snow	spoon	doll	doll
# 172	sheep	sleep	food	same	bite	bad	party	water
# 173	banana	sheep	drink	pull	red	pants	inside	turtle
# 174	hug	touch	cookie	medicine	hello	bottle	dinner	arm
# 175	inside	egg	cute	cookie	truck	read	please	car
# 176	egg	banana	tired	another	tree	hug	people	stop
# 177	sock	flower	airplane	morning	love	bug	cry	food
# 178	later	later	puppy	hurt	dog	cow	run	keys
# 179	touch	cereal	yucky	who	party	picture	pull	break
# 180	dinner	toe	doll	toast	under	doll	cup	egg
# 181	orange	ear	today	bib	pull	stop	love	clean
# 182	fast	sock	sky	look	today	water	under	cow
# 183	choo	lunch	cow	inside	cup	arm	open	peekaboo
# 184	ear	fast	hurt	milk	sing	car	tree	balloon
# 185	apple	dinner	hard	puppy	who	food	bee	wet
# 186	rock	bib	egg	love	bed	keys	ouch	look
# 187	finish	cute	kitchen	hungry	open	under	dog	inside
# 188	elephant	rock	balloon	towel	hit	break	sing	mine
# 189	horse	bread	block	snow	finger	how	stairs	eat
# 190	button	block	wipe	people	her	look	picture	tree
# 191	bib	ouch	car	stop	work	hit	finger	toe
# 192	block	breakfast	ride	cow	touch	peekaboo	who	toast
# 193	ouch	cheerios	clean	why	ear	egg	give	drawer
# 194	soft	horse	hungry	show	stairs	inside	shoe	today
# 195	nap	finish	who	school	school	push	her	refrigerator
# 196	cereal	elephant	dog	squirrel	give	wet	bib	bib
# 197	pig	cake	bib	dinner	ouch	eat	bed	milk
# 198	tongue	soft	touch	where	show	toe	work	hurt
# 199	lunch	choo	same	stove	bib	who	why	take
# 200	cute	nap	eye	hot	couch	toast	show	outside
# 201	blow	apple	rain	tongue	jacket	other	ear	now
# 202	cheerios	pig	hit	cute	yucky	outside	hit	tiger
# 203	cake	bubbles	people	cereal	why	milk	yucky	cry
# 204	arm	blow	nap	sink	when	hurt	couch	hit
# 205	bubbles	button	chicken	purse	shoe	now	touch	other
# 206	bee	picture	shoe	run	hungry	pull	rock	jacket
# 207	sun	sun	stop	wet	sleepy	take	school	hungry
# 208	rain	zipper	sleepy	push	bath	cry	sleepy	under
# 209	splash	morning	bowl	give	picture	watch	car	same
# 210	morning	rain	couch	touch	refrigerator	same	refrigerator	table
# 211	bread	tongue	break	drawer	car	hungry	when	open
# 212	ride	ride	moon	peekaboo	moon	flower	eye	push
# 213	stairs	stairs	hug	ear	chicken	jacket	pattycake	sleepy
# 214	zipper	balloon	star	throw	light	table	bath	pull
# 215	breakfast	thirsty	cry	arm	bad	where	jacket	cookie
# 216	paper	bee	pretty	tired	bug	when	bug	hello
# 217	picture	arm	cold	wipe	shorts	cereal	today	show
# 218	thirsty	paper	run	keys	egg	cookie	chicken	where
# 219	bug	lamb	cake	sleepy	pretty	show	egg	hot
# 220	mouse	mouse	grandma	bye	throw	hello	naughty	why
# 221	fine	fine	cheerios	bump	cute	open	baa	people
# 222	lady	trash	fish	sick	wipe	tired	pretty	cup
# 223	feed	swing	open	pretty	pattycake	sleepy	moon	love
# 224	yucky	lion	watch	refrigerator	eye	why	tiger	tired
# 225	telephone	splash	coat	hello	baa	drawer	wipe	when
# 226	lamb	yucky	please	break	coat	wipe	throw	wipe
# 227	balloon	lady	dirty	sky	break	hot	break	ouch
# 228	lion	star	inside	bee	balloon	love	shorts	chicken
# 229	trash	telephone	picture	cry	mine	cup	cute	school
# 230	towel	grandma	school	pool	tiger	chicken	light	ear
# 231	cry	kitchen	tonight	chicken	hug	people	hug	sick
# 232	star	feed	light	balloon	slide	school	balloon	watch
# 233	dance	dance	refrigerator	hard	same	ear	milk	who
# 234	keys	cry	bee	pajamas	food	ouch	food	dirty
# 235	woof	bug	soap	doll	milk	sick	sick	swing
# 236	slide	kick	banana	open	sick	sink	same	puppy
# 237	kick	towel	tummy	tooth	bring	dirty	hard	sink
# 238	kitchen	slide	pattycake	thirsty	hard	puppy	blue	cereal
# 239	grandma	soap	pool	tiger	fish	orange	mine	run
# 240	soap	keys	close	egg	rock	swing	bring	throw
# 241	tummy	table	rock	yucky	blue	throw	hurt	banana
# 242	table	gentle	fork	eye	hurt	run	purse	give
# 243	tonight	tummy	blue	money	purse	banana	slide	orange
# 244	money	woof	fine	fish	airplane	give	airplane	tongue
# 245	glasses	tonight	zipper	coat	zipper	tongue	fish	pretty
# 246	gentle	couch	sink	orange	banana	pretty	zipper	eye
# 247	frog	turtle	glass	watch	nap	fine	banana	sock
# 248	swing	sky	stroller	cheerios	penguin	elephant	nap	fine
# 249	moon	bump	glasses	under	naughty	cute	close	elephant
# 250	peas	mine	feed	zipper	close	money	dirty	flower
# 251	same	same	under	airplane	dirty	thirsty	star	money
# 252	plant	plant	finish	glass	thirsty	sock	bubbles	baa
# 253	couch	cracker	truck	elephant	star	slide	penguin	bump
# 254	bump	carrots	knee	swim	stroller	bump	thirsty	thirsty
# 255	sky	peas	yard	block	tonight	baa	tonight	cute
# 256	coat	break	thirsty	gentle	sink	purse	cake	purse
# 257	mine	glasses	money	close	trash	bye	stroller	slide
# 258	blanket	coffee	bring	blue	cake	eye	sink	pattycake
# 259	butterfly	blanket	orange	sock	bubbles	tonight	trash	tonight
# 260	break	stroller	slide	fine	sock	pattycake	yard	bye
# 261	stroller	money	shorts	flower	flower	snow	cheerios	snow
# 262	turtle	pool	park	broom	yard	yucky	flower	yucky
# 263	pool	butterfly	dark	bring	cheerios	bee	sock	fish
# 264	doll	comb	pajamas	banana	finish	stove	tummy	stove
# 265	none	doll	when	tummy	tummy	fish	fine	bee
# 266	school	coat	tooth	tonight	swing	pajamas	finish	pajamas
# 267	carrots	airplane	telephone	when	fine	brush	crib	gentle
# 268	refrigerator	sick	clock	finish	clock	hard	swing	close
# 269	medicine	monkey	trash	brush	crib	close	clock	zipper
# 270	tooth	medicine	sock	trash	swim	gentle	apple	apple
# 271	airplane	moon	plant	truck	orange	apple	orange	blue
# 272	monkey	school	flower	telephone	monkey	zipper	turtle	bubbles
# 273	comb	tooth	butterfly	dark	grandma	blue	glass	hard
# 274	clock	frog	squirrel	glasses	brush	cheerios	grandma	cheerios
# 275	yard	jacket	monkey	fork	glass	bubbles	soap	bring
# 276	sick	none	ouch	apple	apple	airplane	glasses	airplane
# 277	cracker	snow	blow	feed	soap	pillow	feed	pillow
# 278	owl	clock	baa	slide	glasses	tummy	swim	tummy
# 279	knee	owl	drawer	blow	feed	bring	monkey	lady
# 280	animal	knee	mine	pattycake	turtle	lady	brush	dark
# 281	jacket	yard	plate	clock	pillow	dark	dark	block
# 282	goose	refrigerator	elephant	stroller	dark	block	vacuum	plant
# 283	snow	animal	dish	park	park	plant	pillow	tooth
# 284	drive	empty	stove	mine	fork	telephone	park	brush
# 285	giraffe	shorts	giraffe	naughty	telephone	finish	fork	telephone
# 286	shorts	vacuum	turtle	dish	money	tooth	telephone	finish
# 287	drawer	hurry	brush	aunt	vacuum	feed	money	feed
# 288	beads	broom	apple	peas	plant	swim	peas	swim
# 289	broom	beads	swing	plant	peas	glasses	plant	glasses
# 290	pajamas	raisin	bump	ouch	elephant	cheek	elephant	blow
# 291	empty	pajamas	tiger	baa	tooth	broom	tooth	cheek
# 292	squirrel	drawer	naughty	knee	pajamas	clock	coffee	broom
# 293	sink	drive	peas	shorts	drawer	blow	pajamas	dish
# 294	sweater	squirrel	owl	beads	coffee	tomorrow	drawer	owl
# 295	scared	goose	aunt	giraffe	bump	dish	uncle	plate
# 296	train	sweater	cheek	plate	giraffe	plate	bump	clock
# 297	turkey	garden	kick	kick	plate	trash	plate	tomorrow
# 298	vacuum	store	beads	owl	uncle	aunt	giraffe	trash
# 299	tiger	pillow	radio	monkey	dish	dry	dish	vacuum
# 300	store	write	jacket	pillow	butterfly	owl	butterfly	coffee
# 301	garden	dark	write	butterfly	blow	monkey	blow	dry
# 302	write	purse	pillow	radio	kick	coffee	radio	aunt
# 303	pillow	train	comb	sweater	radio	vacuum	kick	monkey
# 304	hurry	aunt	vacuum	comb	stove	knee	dry	knee
# 305	glass	fork	sweater	coffee	beads	stroller	beads	park
# 306	radio	sink	scared	write	dry	park	write	kick
# 307	pen	scared	snow	carrots	write	kick	owl	beads
# 308	fork	pen	coffee	uncle	cheek	beads	broom	shorts
# 309	crib	tiger	broom	dry	owl	shorts	cheek	stroller
# 310	toothbrush	turkey	draw	scared	scared	comb	scared	comb
# 311	tomorrow	glass	dry	vacuum	broom	giraffe	stove	butterfly
# 312	swim	giraffe	motorcycle	jacket	sweater	butterfly	sweater	giraffe
# 313	dish	uncle	uncle	garden	lady	radio	lady	radio
# 314	raisin	plate	carrots	hurry	comb	sweater	comb	sweater
# 315	meat	crib	lady	draw	carrots	scared	carrots	hurry
# 316	dark	radio	hurry	motorcycle	draw	carrots	aunt	carrots
# 317	park	park	raisin	cheek	aunt	write	draw	scared
# 318	aunt	teacher	broken	raisin	broken	broken	broken	raisin
# 319	toast	party	turkey	turkey	turkey	garden	turkey	write
# 320	purse	swim	bubbles	bubbles	tomorrow	raisin	tomorrow	broken
# 321	plate	toothbrush	dance	lady	raisin	hurry	raisin	garden
# 322	lamp	meat	tomorrow	dance	hurry	dance	garden	dance
# 323	party	dish	cracker	broken	dance	motorcycle	butter	cracker
# 324	teacher	toast	garden	tomorrow	garden	cracker	hurry	draw
# 325	uncle	lamp	butter	cracker	motorcycle	toothbrush	dance	motorcycle
# 326	grandpa	grandpa	swim	toothbrush	butter	draw	motorcycle	toothbrush
# 327	coffee	butter	toothbrush	butter	lamp	butter	lamp	butter
# 328	broken	draw	penguin	penguin	cracker	turkey	cracker	turkey
# 329	penguin	broken	lion	lion	toothbrush	teacher	toothbrush	teacher
# 330	butter	penguin	lamp	teacher	meat	lion	meat	lion
# 331	draw	donkey	teacher	donkey	lion	donkey	lion	donkey
# 332	stove	stove	donkey	empty	teacher	meat	donkey	meat
# 333	cheek	tomorrow	meat	drive	donkey	empty	empty	empty
# 334	donkey	cheek	empty	meat	empty	drive	teacher	drive
# 335	deer	naughty	drive	deer	drive	deer	drive	deer
# 336	motorcycle	motorcycle	deer	lamp	grandpa	grandpa	grandpa	grandpa
# 337	naughty	pasta	grandpa	grandpa	deer	lamp	deer	lamp
# 338	pasta	deer	pasta	pasta	pasta	pasta	pasta	pasta
